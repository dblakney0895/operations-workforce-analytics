# %% [markdown]
# # Workforce Productivity Analysis
#
# ## Objective
# Analyze workforce productivity metrics to identify trends, inefficiencies, and opportunities for operational improvement.
#
# This analysis focuses on understanding how labor hours, output, and performance indicators interact to support better staffing and decision-making.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {
    "Employee_ID": range(1, 11),
    "Hours_Worked": [40, 38, 45, 50, 42, 36, 48, 44, 39, 41],
    "Units_Produced": [400, 370, 420, 460, 410, 350, 445, 430, 390, 405]
}

df = pd.DataFrame(data)
df
# Out:
#    Employee_ID  Hours_Worked  Units_Produced
# 0            1            40             400
# 1            2            38             370
# 2            3            45             420
# 3            4            50             460
# 4            5            42             410
# 5            6            36             350
# 6            7            48             445
# 7            8            44             430
# 8            9            39             390
# 9           10            41             405

# %%
df["Productivity"] = df["Units_Produced"] / df["Hours_Worked"]

plt.figure()
plt.bar(df["Employee_ID"], df["Productivity"])
plt.xlabel("Employee ID")
plt.ylabel("Productivity (Units per Hour)")
plt.title("Employee Productivity Comparison")
plt.show()

# %%
df["Units_Per_Hour"] = df["Units_Produced"] / df["Hours_Worked"]
df
# Out:
#    Employee_ID  Hours_Worked  Units_Produced  Productivity  Units_Per_Hour
# 0            1            40             400     10.000000       10.000000
# 1            2            38             370      9.736842        9.736842
# 2            3            45             420      9.333333        9.333333
# 3            4            50             460      9.200000        9.200000
# 4            5            42             410      9.761905        9.761905
# 5            6            36             350      9.722222        9.722222
# 6            7            48             445      9.270833        9.270833
# 7            8            44             430      9.772727        9.772727
# 8            9            39             390     10.000000       10.000000
# 9           10            41             405      9.878049        9.878049

# %%
plt.figure()
plt.bar(df["Employee_ID"], df["Units_Per_Hour"])
plt.xlabel("Employee ID")
plt.ylabel("Units Per Hour")
plt.title("Employee Productivity (Units per Hour)")
plt.show()

# %% [markdown]
# ### Key Insight
# Normalizing output by hours worked reveals variability in productivity that is not visible when looking at total units alone. This metric supports more equitable performance comparisons and data-informed staffing decisions.
